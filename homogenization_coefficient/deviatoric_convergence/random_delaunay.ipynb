# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
import pickle

import sys
import os

project_path = os.path.expanduser('~/repos/laplace_operator_metric_graph/')
sys.path.append(project_path)

from construct_graph.graph import Graph, Flat
import construct_graph
from calculations.helper_functions import check_convergence, style_plot

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
nums_Vs = (10**np.linspace(3, 6, 16)).astype(int)[:11]
print(f"num_Vs = {nums_Vs}")

# %%
full_tensors = {}

for num_Vs in nums_Vs:

    print(f"num_Vs = {num_Vs}")

    full_tensors[num_Vs] = {}

    if num_Vs < 39810: 
        upper_lim_seed = 16
    else:
        upper_lim_seed = 8

    max_seeds = np.min((len(coefficients[num_Vs]), upper_lim_seed))

    for seed in range(len(coefficients[num_Vs])):

        if seed < max_seeds:

            np.random.seed(seed)
            rd = construct_graph.patch_graph.Random_Delaunay(num_Vs)
            g = construct_graph.patch_graph.Patch(rd)
            print(f"\nSEED = {seed} / {max_seeds}")
            eq = construct_graph.patch_graph.Cell_Problem(g)
            xi = eq.solve_corrector_equation()
            _, Q, T = eq.construct_homogenized_tensor(xi)

            full_tensors[num_Vs][seed] = (Q, T)

    print("\n")
# Out:
# num_Vs = 1000
# num_Vs = 1584
# num_Vs = 2511
# num_Vs = 3981
# num_Vs = 6309
# num_Vs = 10000
# num_Vs = 15848
#
# SEED = 0 / 16
# Residual too large = 1.575217540717828e-10
#
# SEED = 1 / 16
# Residual too large = 1.2203490305601596e-10
#
# SEED = 2 / 16
# Residual too large = 1.430281580184668e-10
#
# SEED = 3 / 16
# Residual too large = 2.420532422042441e-10
#
# SEED = 4 / 16
# Residual too large = 1.3232500963582337e-10
#
# SEED = 5 / 16
# Residual too large = 1.559871362342736e-10
#
# SEED = 6 / 16
# Residual too large = 3.309247957933713e-10
#
# SEED = 7 / 16
# Residual too large = 4.049496493299559e-10
#
# SEED = 8 / 16
# Residual too large = 1.4558489749560431e-10
#
# SEED = 9 / 16
# Residual too large = 1.3989823134510861e-10
#
# SEED = 10 / 16
# Residual too large = 1.2766587938262616e-10
#
# SEED = 11 / 16
# Residual too large = 1.5403565847590814e-10
#
# SEED = 12 / 16
# Residual too large = 1.3442815277193833e-10
#
# SEED = 13 / 16
# Residual too large = 1.9608870696440515e-10
#
# SEED = 14 / 16
# Residual too large = 1.5211877995393773e-10
#
# SEED = 15 / 16
# Residual too large = 1.7340987056994739e-10
#
#
# num_Vs = 25118
#
# SEED = 0 / 16
# Residual too large = 2.931199465311536e-10
#
# SEED = 1 / 16
# Residual too large = 2.2114949882802924e-10
#
# SEED = 2 / 16
# Residual too large = 2.418018987975458e-10
#
# SEED = 3 / 16
# Residual too large = 3.4215653823137497e-10
#
# SEED = 4 / 16
# Residual too large = 2.2842027226221096e-10
#
# SEED = 5 / 16
# Residual too large = 2.586274169094401e-10
#
# SEED = 6 / 16
# Residual too large = 2.7818494348857297e-10
#
# SEED = 7 / 16
# Residual too large = 3.4806761767044434e-10
#
# SEED = 8 / 16
# Residual too large = 2.7734664139240807e-10
#
# SEED = 9 / 16
# Residual too large = 2.7077255567888113e-10
#
# SEED = 10 / 16
# Residual too large = 2.3972318462574937e-10
#
# SEED = 11 / 16
# Residual too large = 2.470609256683225e-10
#
# SEED = 12 / 16
# Residual too large = 2.5571220018991707e-10
#
# SEED = 13 / 16
# Residual too large = 3.2150048600084834e-10
#
# SEED = 14 / 16
# Residual too large = 2.958134991710384e-10
#
# SEED = 15 / 16
# Residual too large = 2.9092091522977703e-10
#
#
# num_Vs = 39810
#
# SEED = 0 / 8
# Residual too large = 6.017112296885746e-10
#
# SEED = 1 / 8
# Residual too large = 4.183198508498206e-10
#
# SEED = 2 / 8
# Residual too large = 4.2778601610057064e-10
#
# SEED = 3 / 8
# Residual too large = 4.990418286723018e-10
#
# SEED = 4 / 8
# Residual too large = 4.4727571904053686e-10
#
# SEED = 5 / 8
# Residual too large = 5.574959474334561e-10
#
# SEED = 6 / 8
# Residual too large = 5.296346315652435e-10
#
# SEED = 7 / 8
# Residual too large = 7.591960970862058e-10
#
#
# num_Vs = 63095
#
# SEED = 0 / 8
# Residual too large = 9.648396992394755e-10
#
# SEED = 1 / 8
# Residual too large = 8.137692346101113e-10
#
# SEED = 2 / 8
# Residual too large = 8.312141751448135e-10
#
# SEED = 3 / 8
# Residual too large = 9.895073590536186e-10
#
# SEED = 4 / 8
# Residual too large = 8.297935617969984e-10
#
# SEED = 5 / 8
# Residual too large = 1.0059349775483745e-09
#
# SEED = 6 / 8
# Residual too large = 9.796000816226835e-10
#
# SEED = 7 / 8
# Residual too large = 8.803115046914006e-10
#
#
# num_Vs = 100000
#
# SEED = 0 / 8
# Residual too large = 1.729195341198118e-09
#
# SEED = 1 / 8
# Residual too large = 1.4668326570697336e-09
#
# SEED = 2 / 8
# Residual too large = 1.9627359233372195e-09
#
# SEED = 3 / 8
# Residual too large = 1.8283599658200377e-09
#
# SEED = 4 / 8
# Residual too large = 1.8629249920101077e-09
#
# SEED = 5 / 8
# Residual too large = 2.4144455446093242e-09
#
# SEED = 6 / 8
# Residual too large = 1.6201993909138485e-09
#
# SEED = 7 / 8
# Residual too large = 1.8355775958889136e-09

# %%
rel_errs = {}

for num_Vs in full_tensors:

    rel_errs[num_Vs] = []

    for seed in full_tensors[num_Vs]:

        R = full_tensors[num_Vs][seed][0] 
        rel_err = np.linalg.norm(R - np.trace(R) / 2 * np.eye(2)) / np.linalg.norm(np.trace(R) / 2 * np.eye(2))
        rel_errs[num_Vs].append(rel_err)

# %%
x = np.array(list(rel_errs.keys()))
y = np.array([np.mean(i) for i in rel_errs.values()])
dy = np.array([np.std(i) for i in rel_errs.values()])

y_ratio_upper = y * (1 + dy / y)  # Equivalent to y + dy
y_ratio_lower = y / (1 + dy / y)  # Avoids y - dy < 0
y_err_upper = (y_ratio_upper - y)
y_err_lower = (y - y_ratio_lower)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10))

eigenvalue_linewidth = 3
eigenvalue_markersize = 15

ax.errorbar(x, y, yerr=[y_err_lower, y_err_upper], capsize=8, c='b', alpha=0.5, zorder=0)
ax.loglog(x, y, 'o-', c='b', linewidth=eigenvalue_linewidth, markersize=eigenvalue_markersize)

ax.loglog(x, x**(-0.5) * 1.5, '--', c='r', linewidth=eigenvalue_linewidth)

style_plot(fig, ax, aspect=None)

plt.show()
